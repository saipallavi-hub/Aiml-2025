# %% [markdown]
# <a href="https://colab.research.google.com/github/saipallavi-hub/Aiml-2025/blob/main/19_11_Lab_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/MilkQuality.csv")
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %%
print("/content/MilkQuality.csv.")
# Out:
# /content/MilkQuality.csv.

# %%
print("\nDataset Information:")
print(df.info())
print("\nFirst few rows of the dataset:")
print(df.head())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1059 entries, 0 to 1058
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pH          1059 non-null   float64
#  1   Temprature  1059 non-null   int64
#  2   Taste       1059 non-null   int64
#  3   Odor        1059 non-null   int64
#  4   Fat         1059 non-null   int64
#  5   Turbidity   1059 non-null   int64
#  6   Colour      1059 non-null   int64
#  7   Grade       1059 non-null   object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 66.3+ KB
# None
#
# First few rows of the dataset:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# ...

# %%
grade_mapping = {'low': 0, 'medium': 1, 'high': 2}
df['Grade_numeric'] = df['Grade'].map(grade_mapping)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Grade', data=df, palette="viridis")
plt.title('Distribution of Milk Grades')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-22-64677e2e7208>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Grade', data=df, palette="viridis")

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
